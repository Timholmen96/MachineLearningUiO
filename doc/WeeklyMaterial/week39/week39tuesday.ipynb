# %% [markdown]
# # Week 39, Tuesday session: how to write the report
#
# **FYS-STK3155/4155, Tuesday September 22, 2026.**
#
# Mondays are lectures; Tuesdays belong to your questions and to concrete cases.
# Today the case is not a piece of code but a piece of text: the Project 1
# report you hand in on **October 5**. Two cases, worked in your project group in
# this notebook (edit the markdown cells — they are your draft):
#
# * **Case 1:** the abstract and the introduction.
# * **Case 2:** the conclusion, the reference list, and the appendix that
#   declares how you used large language models.
#
# These five pieces are also this week's exercises (`exercisesweek39.ipynb`,
# deadline **Friday September 25 at midnight**); you get short feedback before
# the project deadline and reuse them in the report.
#
# Sources: the course guide *How to write a scientific project*
# ([projectwriting](https://github.com/CompPhysics/MachineLearning/blob/master/doc/Projects/ProjectWriting/projectwriting.do.txt)),
# the grading template
# ([EvaluationForm.md](https://github.com/CompPhysics/MachineLearning/blob/master/doc/Projects/EvaluationGrading/EvaluationForm.md)),
# a LaTeX example in the revtex style
# ([latexexample.tex](https://github.com/CompPhysics/MachineLearning/blob/master/doc/Projects/ProjectWriting/latexexample.tex)),
# an earlier report ([ReportSample.pdf](https://github.com/CompPhysics/MachineLearning/blob/master/doc/Projects/ReportExample/ReportSample.pdf)),
# and the [LLM usage declaration guidelines](https://github.com/EducationalMaterialUiO/MachineLearningUiO/blob/main/LLM_Usage_Declaration_Guidelines.md).
#
# ## How Project 1 is graded (100 points)
#
# | Criterion | Points |
# |---|---:|
# | Abstract: accurate and informative? | 5 |
# | Introduction: status of the problem and the major objectives | 10 |
# | Formalism/methods: discussion of the methods and their suitability | 10 |
# | Code, implementation and testing: readability, tests, benchmarks | 10 |
# | Analysis of results: selection, presentation, understanding | 40 |
# | Conclusions, discussions and critical comments; future improvements | 10 |
# | LLM declaration | 5 |
# | Overall presentation: figures, tables, algorithms | 5 |
# | Referencing: relevant works cited accurately? | 5 |
#
# Today's five pieces are worth 35 points before a single number is computed.

# %% [markdown]
# ## The tool: writing the report in LaTeX with Overleaf
#
# We ask for the report as a scientific article typeset in LaTeX.
# [Overleaf](https://www.overleaf.com) is LaTeX in the browser: nothing to
# install, the PDF next to the source, and the whole group writes in the same
# document, with history and comments.
#
# 1. Log in at [overleaf.com](https://www.overleaf.com) with your UiO e-mail
#    (single sign-on), or make a free account.
# 2. Download the course template
#    [FYS_STK_Template.zip](https://github.com/CompPhysics/MachineLearning/blob/master/doc/LectureNotes/data/FYS_STK_Template.zip)
#    and upload it as a *New Project → Upload Project*. It contains `main.tex`,
#    `biblio.bib` and a `Figures/` folder.
# 3. *Share* the project with your group. To Canvas you send the exported PDF
#    and the link to your GitHub repository, not the Overleaf link.
#
# The handful of commands you need today:
#
# ```latex
# \section{Results}\label{sec:results}
# Figure~\ref{fig:mse} shows the test MSE for Ridge \cite{hoerl1970}.
# \begin{figure}
#   \includegraphics[width=\linewidth]{Figures/mse_ridge.pdf}
#   \caption{Test MSE against $\lambda$.}
#   \label{fig:mse}
# \end{figure}
# \bibliography{biblio}
# ```
#
# Habits that save you the last night: save figures from the code as PDF
# (`plt.savefig("mse_ridge.pdf")`) and upload them, never screenshots; refer
# with `\label`/`\ref` and `\cite`, never with typed numbers; keep one `.bib`
# file and check every entry against its source (Case 2 below — the templates
# printed in this notebook paste directly into `main.tex` and `biblio.bib`).
# If you prefer to work offline, TeX Live or MacTeX with VS Code (LaTeX
# Workshop) compiles the same files.

# %% [markdown]
# ## Case 1: the abstract and the introduction
#
# **Goal:** leave with a draft abstract and a draft introduction that you will
# reuse in the report. One document per group, everybody writes.
#
# ### Step 1: read two abstracts and mark the five moves
#
# The grading guide says an abstract can be structured as
#
# 1. a short introduction to the topic and why it is important,
# 2. a challenge or unresolved issue with the topic,
# 3. what you have done to address it,
# 4. the main results,
# 5. the implications.
#
# **Abstract A** (from a recent Physical Review Letter, quoted in the course
# guide; three sentences):
#
# > *We construct the first four-dimensional multiple black hole solution of
# > general relativity with a positive cosmological constant. The solution
# > consists of two static black holes whose gravitational attraction is
# > balanced by the cosmic expansion. These static binaries provide the first
# > four-dimensional example of nonuniqueness in general relativity without
# > matter.*
#
# **Abstract B** (a Project 1 example; the numbers in brackets are placeholders):
#
# > Polynomial regression is the simplest setting in which the central
# > questions of supervised learning — model complexity, regularisation and the
# > reliability of an error estimate — can be studied exactly. We fit Runge's
# > function $1/(1+25x^2)$ on $[-1,1]$, sampled at $n=[\,]$ points with Gaussian
# > noise of standard deviation $[\,]$, with polynomials of degree up to 15 using
# > ordinary least squares, Ridge and Lasso regression, and we compare the
# > closed-form estimators with our own implementations of gradient descent,
# > momentum, AdaGrad, RMSProp, Adam and stochastic gradient descent. Model
# > selection is done by the bootstrap and by $k$-fold cross-validation, and the
# > test error is decomposed into bias and variance. We find that the test error
# > is minimised at degree $[\,]$ for OLS and that Ridge with $\lambda=[\,]$
# > extends the usable range of degrees to $[\,]$ at the price of a bias of
# > $[\,]$; Lasso sets $[\,]$ of the $[\,]$ coefficients to zero at the
# > cross-validated $\lambda$. Gradient descent reproduces the closed-form
# > solutions to $[\,]$ within $[\,]$ iterations only after the features are
# > standardised, and Adam is the most robust to the choice of learning rate.
# > Our results illustrate that resampling, not the training error, decides the
# > model, and that the optimiser and the preprocessing are part of the model.
#
# For each abstract, write next to every sentence which move (1–5) it makes.
# Which moves does the three-sentence abstract A skip, and why can it afford to?

# %% [markdown]
# ### Step 2: write your abstract
#
# Rules: 120–180 words, one paragraph, no citations, no equations, past tense
# for what you did, present tense for what is true, "we" also for a single
# author. Numbers you do not have yet go in as placeholders. Every sentence must
# survive the question *so what?*
#
# **Your abstract (edit this cell):**
#
# > *Move 1 — topic and why it matters:* ...
# >
# > *Move 2 — the question:* ...
# >
# > *Move 3 — what we did (say what is our own code and what is a library):* ...
# >
# > *Move 4 — the main result, as a number or a comparison:* ...
# >
# > *Move 5 — the implication, one sentence, not a platitude:* ...
#
# Then delete the labels and read it aloud. Paste it into the cell below to
# count the words.

# %%
abstract = """
Paste your abstract here.
"""

words = abstract.split()
print(f"{len(words)} words; target 120-180")
banned = ["in this report we will", "in this project we will", "machine learning is",
          "in recent years", "very", "extremely"]
for phrase in banned:
    if phrase in abstract.lower():
        print(f"  consider removing: '{phrase}'")
# Out:
# 4 words; target 120-180

# %% [markdown]
# ### Step 3: the first and the last paragraph of the introduction
#
# The introduction has three jobs (course guide): motivate the reader, say what
# you have done, and give the structure of the report. Write the first and the
# last paragraph now; the middle is a bullet list for today.
#
# **Paragraph 1 — motivation (the reader's problem, not yours):** why does
# anyone fit functions with polynomials? Why is Runge's function the classic
# test? What goes wrong at high degree, and what is the general lesson
# (bias–variance, Section 2.10 of the book)? Cite the sources you actually used.
#
# > ...
#
# **Middle paragraphs — what has been done and what you do (bullets for now):**
#
# * the linear models: OLS, Ridge, Lasso (Chapter 3), one sentence each on what
#   the penalty does;
# * the resampling methods: bootstrap and $k$-fold cross-validation (Sections
#   2.11 and 3.14);
# * the optimisers: gradient descent, momentum, AdaGrad, RMSProp, Adam, SGD
#   (Chapter 4), and the analytical gradient checked against automatic
#   differentiation;
# * what is **yours**: own implementations of ..., own derivation of ...; and
#   what is a library call (cross-validation with `scikit-learn` is fine — say
#   so).
#
# **Last paragraph — the structure of the report, one sentence per section:**
#
# > Section 2 presents the models and the bias–variance decomposition; Section 3
# > describes our implementation and the tests against the closed-form
# > solutions; Section 4 presents the results, first for OLS, then Ridge and
# > Lasso, then the optimisers; Section 5 concludes. The code is available at
# > [URL].
#
# What does **not** belong in the introduction: results (they come in Section 4
# — the abstract may quote them), long derivations, definitions of MSE and $R^2$
# (Methods), a history of machine learning.
#
# ### Step 4: swap with a neighbouring group
#
# Grade each other's abstract with the form's question — *accurate and
# informative?* — and circle every sentence that could appear in *any* Project 1
# report. Those sentences carry no information.

# %% [markdown]
# ### Case 1: do you have the insight?
#
# 1. A group writes "In this project we will implement OLS, Ridge and Lasso and
#    study the bias–variance trade-off" as their abstract. Which of the five
#    moves are present, which are missing, and why is the tense wrong?
# 2. Your test MSE for OLS is lowest at degree 7 with the value 0.0121 (noise
#    variance 0.01). Does this number belong in the abstract, in the
#    introduction, in both, or in neither?
# 3. The introduction's last paragraph lists the sections. Why do we insist on
#    it, when the table of contents already does that?
# 4. You used `scikit-learn` for cross-validation and your own code for
#    everything else. Where in the introduction does the reader learn this, and
#    why does it matter for the grade?
#
# Write your answers here before the plenary:
#
# > 1. ...
# > 2. ...
# > 3. ...
# > 4. ...

# %% [markdown]
# ## Case 2: the conclusion, the references, and the declaration of LLM use
#
# **Goal:** a draft conclusion, a reference list in the required format, and the
# LLM appendix filled in for what you have actually done so far.
#
# ### Step 1: the conclusion, three paragraphs
#
# A conclusion is not a second abstract. The course guide asks for three
# things: state the main findings and their interpretation; discuss the pros
# and cons of the methods and possible improvements; present perspectives for
# future work.
#
# **(i) Main findings, explained.** The abstract's numbers, now with the
# *reason*. Illustrative example (invented numbers):
#
# > At degree 7 the bias of the OLS fit (0.003) and its variance (0.008) are of
# > the same size, and both bootstrap and 10-fold cross-validation locate the
# > minimum there; beyond degree 9 the variance grows by a factor of $[\,]$ per
# > degree while the bias no longer decreases. Ridge damps the variance in the
# > directions of the small singular values of $\boldsymbol{X}$ (Section 3.8),
# > which is why it extends the usable degree; the bias it introduces is visible
# > as the systematic underestimate of the peak of $f$. Lasso's zeros coincide
# > with the odd powers, as the symmetry of $f$ requires — a check that the
# > penalty selects, not merely shrinks.
#
# **(ii) The critical paragraph — write this one first.** What the methods
# could and could not do, what you would do differently, where your results are
# least certain:
#
# > Our bias–variance estimates use the known $f$; on real data the bias term
# > would absorb the noise variance, and our numbers are optimistic by
# > $\sigma^2$. The gradient-descent comparisons were run at a fixed number of
# > iterations rather than to a tolerance, which favours Adam; and the learning
# > rates were scanned on a grid of 16 values, coarse enough that the ranking of
# > momentum and RMSProp at degree 10 is not resolved.
#
# **(iii) Perspectives, concretely** — the one or two things you would do next
# and why, not "more research is needed":
#
# > A natural next step is the Lasso path with warm starts along $\lambda$,
# > which would replace the $[\,]$ separate fits by one; and a validation-based
# > stopping rule for SGD, which would remove the iteration count as a
# > hyperparameter. Both are needed before the same pipeline is applied to the
# > classification data of Project 2.
#
# **Your conclusion (edit this cell):**
#
# > (i) ...
# >
# > (ii) ...
# >
# > (iii) ...

# %% [markdown]
# ### Step 2: references — what to cite, and how
#
# Cite what you *used*: the origin of a method, the text you learned it from,
# the software you depend on, the data. Not: things you did not read. The course
# format is
#
# * **articles:** name(s) of author(s), journal, **volume** (boldfaced), page
#   (year);
# * **books:** name(s) of author(s), title of book, publisher, place, year.
#
# With `revtex` (see `latexexample.tex`) this is `\bibliographystyle{apsrev4-1}`;
# with the `article` class, `unsrt` or `plain`. Cite every entry at least once
# with `\cite{key}` — BibTeX drops uncited entries, and so does the grader.
#
# A starting `.bib` file for Project 1 (copy what you use, add what you used):
#
# ```bibtex
# @book{hastie2009,
#   author    = {Hastie, Trevor and Tibshirani, Robert and Friedman, Jerome},
#   title     = {The Elements of Statistical Learning: Data Mining, Inference, and Prediction},
#   edition   = {2},
#   publisher = {Springer},
#   address   = {New York},
#   year      = {2009}
# }
# @book{goodfellow2016,
#   author    = {Goodfellow, Ian and Bengio, Yoshua and Courville, Aaron},
#   title     = {Deep Learning},
#   publisher = {MIT Press},
#   address   = {Cambridge, MA},
#   year      = {2016}
# }
# @misc{hjorthjensen2026,
#   author       = {Hjorth-Jensen, Morten},
#   title        = {Applied Data Analysis and Machine Learning: Lecture Notes},
#   howpublished = {\url{https://github.com/CompPhysics/MachineLearning}},
#   year         = {2026}
# }
# @article{hoerl1970,
#   author  = {Hoerl, Arthur E. and Kennard, Robert W.},
#   title   = {Ridge Regression: Biased Estimation for Nonorthogonal Problems},
#   journal = {Technometrics},
#   volume  = {12},
#   pages   = {55--67},
#   year    = {1970}
# }
# @article{tibshirani1996,
#   author  = {Tibshirani, Robert},
#   title   = {Regression Shrinkage and Selection via the Lasso},
#   journal = {Journal of the Royal Statistical Society: Series B},
#   volume  = {58},
#   pages   = {267--288},
#   year    = {1996}
# }
# @inproceedings{kingma2015,
#   author    = {Kingma, Diederik P. and Ba, Jimmy},
#   title     = {Adam: A Method for Stochastic Optimization},
#   booktitle = {International Conference on Learning Representations (ICLR)},
#   year      = {2015},
#   note      = {arXiv:1412.6980}
# }
# @article{duchi2011,
#   author  = {Duchi, John and Hazan, Elad and Singer, Yoram},
#   title   = {Adaptive Subgradient Methods for Online Learning and Stochastic Optimization},
#   journal = {Journal of Machine Learning Research},
#   volume  = {12},
#   pages   = {2121--2159},
#   year    = {2011}
# }
# @article{robbins1951,
#   author  = {Robbins, Herbert and Monro, Sutton},
#   title   = {A Stochastic Approximation Method},
#   journal = {The Annals of Mathematical Statistics},
#   volume  = {22},
#   pages   = {400--407},
#   year    = {1951}
# }
# @article{bottou2018,
#   author  = {Bottou, L{\'e}on and Curtis, Frank E. and Nocedal, Jorge},
#   title   = {Optimization Methods for Large-Scale Machine Learning},
#   journal = {SIAM Review},
#   volume  = {60},
#   pages   = {223--311},
#   year    = {2018}
# }
# @article{pedregosa2011,
#   author  = {Pedregosa, Fabian and Varoquaux, Ga{\"e}l and Gramfort, Alexandre and Michel, Vincent and Thirion, Bertrand and Grisel, Olivier and Blondel, Mathieu and Prettenhofer, Peter and Weiss, Ron and Dubourg, Vincent and Vanderplas, Jake and Passos, Alexandre and Cournapeau, David and Brucher, Matthieu and Perrot, Matthieu and Duchesnay, {\'E}douard},
#   title   = {Scikit-learn: Machine Learning in {P}ython},
#   journal = {Journal of Machine Learning Research},
#   volume  = {12},
#   pages   = {2825--2830},
#   year    = {2011}
# }
# @article{harris2020,
#   author  = {Harris, Charles R. and Millman, K. Jarrod and van der Walt, St{\'e}fan J. and others},
#   title   = {Array programming with {NumPy}},
#   journal = {Nature},
#   volume  = {585},
#   pages   = {357--362},
#   year    = {2020}
# }
# @misc{jax2018,
#   author       = {Bradbury, James and Frostig, Roy and Hawkins, Peter and Johnson, Matthew James and Leary, Chris and Maclaurin, Dougal and Necula, George and Paszke, Adam and VanderPlas, Jake and Wanderman-Milne, Skye and Zhang, Qiao},
#   title        = {{JAX}: composable transformations of {P}ython+{N}um{P}y programs},
#   howpublished = {\url{http://github.com/google/jax}},
#   year         = {2018}
# }
# @article{runge1901,
#   author  = {Runge, Carl},
#   title   = {{\"U}ber empirische Funktionen und die Interpolation zwischen {\"a}quidistanten Ordinaten},
#   journal = {Zeitschrift f{\"u}r Mathematik und Physik},
#   volume  = {46},
#   pages   = {224--243},
#   year    = {1901}
# }
# ```
#
# Without BibTeX, the same entries as `\bibitem`s in the course format:
#
# ```latex
# \begin{thebibliography}{99}
# \bibitem{hastie2009} T. Hastie, R. Tibshirani and J. Friedman,
#   \emph{The Elements of Statistical Learning}, 2nd ed., Springer, New York, 2009.
# \bibitem{tibshirani1996} R. Tibshirani, J. R. Stat. Soc. B \textbf{58}, 267 (1996).
# \bibitem{hoerl1970} A. E. Hoerl and R. W. Kennard, Technometrics \textbf{12}, 55 (1970).
# \bibitem{pedregosa2011} F. Pedregosa \emph{et al.}, J. Mach. Learn. Res. \textbf{12}, 2825 (2011).
# \end{thebibliography}
# ```
#
# ### Step 3: verify every reference — against the source, not against an LLM
#
# Open the journal page or the DOI. Check authors, year, volume, pages, and that
# the source says what you claim. Language models invent plausible references
# with real authors and wrong details, and do so confidently. **Two of the
# following five references are wrong on purpose.** Find them (the answers are
# at the end of the notebook):
#
# 1. R. Tibshirani, *Regression Shrinkage and Selection via the Lasso*,
#    J. R. Stat. Soc. B **58**, 267 (1996).
# 2. A. E. Hoerl and R. W. Kennard, *Ridge Regression: Biased Estimation for
#    Nonorthogonal Problems*, Technometrics **14**, 55 (1972).
# 3. D. P. Kingma and J. Ba, *Adam: A Method for Stochastic Optimization*,
#    Advances in Neural Information Processing Systems **30**, 1 (2017).
# 4. H. Robbins and S. Monro, *A Stochastic Approximation Method*,
#    Ann. Math. Statist. **22**, 400 (1951).
# 5. F. Pedregosa *et al.*, *Scikit-learn: Machine Learning in Python*,
#    J. Mach. Learn. Res. **12**, 2825 (2011).

# %% [markdown]
# ### Step 4: the LLM appendix
#
# The rules are in the [guidelines](https://github.com/EducationalMaterialUiO/MachineLearningUiO/blob/main/LLM_Usage_Declaration_Guidelines.md);
# in short:
#
# * LLMs (ChatGPT, Claude, Copilot, Gemini, ...) are **permitted and
#   encouraged**. Using one does not reduce your responsibility: every result,
#   derivation, code block and argument must be something you understand, can
#   defend, and have verified.
# * Declare **significant** use — content, logic or structure that appears in
#   the submission. Using an LLM as a tutor and then writing in your own words
#   is not declared; a literature search whose citations you verified is not
#   declared. Concealment, not use, is the integrity violation.
# * Add an appendix **"Use of AI/LLM Tools"** with: A.1 the tools (name,
#   version or access date, access method); A.2 one contribution level per
#   *section* of the report; A.3 one level per *code file*. Level 3 text and
#   level 3–4 code get a sentence on the prompt and on what you changed.
# * In the code: a `LLM-assisted` tag in the docstring of every function at
#   level 2 or above; an inline comment for shorter LLM-generated blocks; a
#   markdown note above assisted notebook cells.
#
# | Text level | Meaning |
# |---|---|
# | 0 None | no LLM assistance |
# | 1 Language only | spell-check, grammar, minor phrasing |
# | 2 Editorial | LLM rewrote or restructured your sentences; you supplied the ideas and checked the result |
# | 3 Generative | LLM drafted substantial text from your prompts; you revised, verified and own it |
#
# | Code level | Meaning |
# |---|---|
# | 0 None | no LLM assistance |
# | 1 Debugging | LLM identified a bug; you implemented the fix |
# | 2 Snippet | LLM provided a function, loop or short block; you integrated and tested it |
# | 3 Skeleton | LLM generated the structure of a script/class; you filled in the logic |
# | 4 Substantial | LLM wrote most of a file; you adapted, tested and commented it |
#
# Fill in the two tables below for **what you have actually done so far** — the
# abstract and introduction you just wrote, and the code you have. The helper
# prints them as LaTeX and as markdown; paste the LaTeX into your report.

# %%
def llm_appendix(tools, text_rows, code_rows, fmt="latex"):
    """Render the 'Use of AI/LLM Tools' appendix as LaTeX (default) or markdown.

    tools:     list of strings, e.g. ["Claude (claude.ai, Sept-Oct 2026)"]
    text_rows: list of (section, level 0-3, note)
    code_rows: list of (file, level 0-4, description)
    """
    if fmt == "latex":
        out = ["\\section*{Appendix A: Use of AI/LLM tools}",
               "\\textbf{A.1 Tools used.} " + ("; ".join(tools) if tools else "None") + ".",
               "", "\\textbf{A.2 Text writing and editing.}",
               "\\begin{tabular}{llp{7cm}}", "Section & Level & Notes\\\\ \\hline"]
        out += [f"{s} & {l} & {n}\\\\" for s, l, n in text_rows]
        out += ["\\end{tabular}", "", "\\textbf{A.3 Code generation and assistance.}",
                "\\begin{tabular}{llp{7cm}}", "File / notebook & Level & Description\\\\ \\hline"]
        out += [f"\\texttt{{{f}}} & {l} & {d}\\\\" for f, l, d in code_rows]
        out += ["\\end{tabular}"]
    else:
        out = ["### Appendix A: Use of AI/LLM tools", "",
               "**A.1 Tools used:** " + ("; ".join(tools) if tools else "None"), "",
               "**A.2 Text**", "", "| Section | Level | Notes |", "|---|---|---|"]
        out += [f"| {s} | {l} | {n} |" for s, l, n in text_rows]
        out += ["", "**A.3 Code**", "", "| File | Level | Description |", "|---|---|---|"]
        out += [f"| `{f}` | {l} | {d} |" for f, l, d in code_rows]
    return "\n".join(out)


# Fill these in for YOUR project -- the entries below are an example only
tools = ["Claude (claude.ai, September 2026)",
         "GitHub Copilot (VS Code, throughout)"]
text_rows = [("Abstract", 1, "grammar check"),
             ("Introduction", 2, "two paragraphs rephrased for clarity; ideas and structure ours"),
             ("Theory / Methods", 0, "--"),
             ("Results", 0, "--"),
             ("Conclusion", 1, "minor language corrections")]
code_rows = [("regression.py", 0, "written independently"),
             ("optimisers.py", 2, "Copilot suggested the Adam bias-correction lines; "
                                 "tested against the closed-form OLS solution"),
             ("resampling.py", 1, "Claude found an off-by-one error in the k-fold split"),
             ("plots.ipynb", 1, "Copilot debugged an axis-indexing bug")]

print(llm_appendix(tools, text_rows, code_rows, fmt="latex"))
print()
print(llm_appendix(tools, text_rows, code_rows, fmt="markdown"))
# Out:
# \section*{Appendix A: Use of AI/LLM tools}
# \textbf{A.1 Tools used.} Claude (claude.ai, September 2026); GitHub Copilot (VS Code, throughout).
#
# \textbf{A.2 Text writing and editing.}
# \begin{tabular}{llp{7cm}}
# Section & Level & Notes\\ \hline
# Abstract & 1 & grammar check\\
# Introduction & 2 & two paragraphs rephrased for clarity; ideas and structure ours\\
# Theory / Methods & 0 & --\\
# Results & 0 & --\\
# Conclusion & 1 & minor language corrections\\
# \end{tabular}
#
# \textbf{A.3 Code generation and assistance.}
# \begin{tabular}{llp{7cm}}
# File / notebook & Level & Description\\ \hline
# \texttt{regression.py} & 0 & written independently\\
# \texttt{optimisers.py} & 2 & Copilot suggested the Adam bias-correction lines; tested against the closed-form OLS solution\\
# \texttt{resampling.py} & 1 & Claude found an off-by-one error in the k-fold split\\
# \texttt{plots.ipynb} & 1 & Copilot debugged an axis-indexing bug\\
# \end{tabular}
#
# ...

# %% [markdown]
# And in the code itself, for every function at level 2 or above:
#
# ```python
# def adam_step(theta, g, state, t, gamma=1e-3, beta1=0.9, beta2=0.999, eps=1e-8):
#     """One Adam update, Eqs. (4.51)-(4.55) of the lecture notes.
#
#     LLM-assisted
#     ------------
#     Tool: GitHub Copilot (September 2026)
#     Role: suggested the bias-correction lines m_hat, v_hat.
#     Modifications: state handling and the eps placement written by us;
#     verified against the closed-form OLS solution on the degree-2 test problem.
#     """
#     ...
# ```
#
# and above an assisted notebook cell:
#
# > **LLM note:** the following cell was generated with Claude assistance
# > (level 3 skeleton). The bootstrap loop was written by the LLM; the
# > bias–variance bookkeeping and the plots were implemented independently.
#
# ### Case 2: do you have the insight?
#
# 1. You asked an LLM to explain the bias–variance decomposition, then wrote
#    Section 2.3 yourself from your own notes. Level? And if you pasted its
#    derivation and fixed the notation?
# 2. Copilot autocompleted most of your plotting code line by line. Does every
#    accepted line need a comment? What goes in the appendix?
# 3. A reference in your list has the right authors, the right journal and the
#    wrong year and pages. Whose error is it, and how would the grader find it?
# 4. Your conclusion's critical paragraph says the learning-rate grid was too
#    coarse to rank two optimisers. Does admitting this lower or raise your score
#    under "Conclusions, discussions and critical comments"?
#
# > 1. ...
# > 2. ...
# > 3. ...
# > 4. ...

# %% [markdown]
# ## Before you leave
#
# * **What you should own now:** a draft abstract with the five moves and
#   placeholders for numbers; the first and last paragraph of the introduction;
#   a three-paragraph conclusion with a critical paragraph; a verified `.bib`
#   file in the course format; and the LLM appendix filled in for the work done
#   so far, consistent with the docstrings in your code.
# * **Weekly exercises** (`exercisesweek39.ipynb`): exactly these five pieces,
#   for your own Project 1. Deadline **Friday September 25 at midnight**.
# * **Project 1** is due **October 5**.
# * **Next Monday (week 40):** neural networks (Chapter 8).
#
# ---
#
# **Answers to the reference check (Step 3 of Case 2).** References 2 and 3 are
# wrong. Hoerl and Kennard's Ridge paper is Technometrics **12**, 55 (1970),
# not volume 14 of 1972. Adam (Kingma and Ba) was presented at the International
# Conference on Learning Representations, ICLR 2015 (arXiv:1412.6980), not in
# NeurIPS 2017 — and NeurIPS proceedings have no volume/page numbers of that
# form. The other three are correct.
