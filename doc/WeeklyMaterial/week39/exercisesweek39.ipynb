# %% [markdown]
# # Exercises week 39
#
# **FYS-STK3155/4155, fall 2026 — deadline Friday September 25 at midnight.**
#
# ## Writing the report: abstract, introduction, conclusion, references and the LLM declaration
#
# The aim of the exercises this week is to aid you in getting started with
# writing the report for Project 1 (deadline October 5). The Tuesday session of
# week 39 is devoted to exactly these exercises (`week39tuesday.ipynb` and the
# Tuesday slides). You write five pieces of your own Project 1 report: the
# abstract, the introduction, the conclusion, the reference list, and the
# appendix that declares how you have used large language models. A short
# feedback to this exercise will be available before the project deadline, and
# you reuse these elements in your final report.
#
# Read first:
#
# * the grading template, which doubles as a guide on how to write a report:
#   [EvaluationForm.md](https://github.com/CompPhysics/MachineLearning/blob/master/doc/Projects/EvaluationGrading/EvaluationForm.md);
# * the slides *How to write a scientific project*:
#   [projectwriting](https://github.com/CompPhysics/MachineLearning/blob/master/doc/Projects/ProjectWriting/projectwriting.do.txt),
#   and a LaTeX example in the revtex style:
#   [latexexample.tex](https://github.com/CompPhysics/MachineLearning/blob/master/doc/Projects/ProjectWriting/latexexample.tex);
# * an example of an earlier project:
#   [ReportSample.pdf](https://github.com/CompPhysics/MachineLearning/blob/master/doc/Projects/ReportExample/ReportSample.pdf);
# * the rules for declaring the use of large language models:
#   [LLM_Usage_Declaration_Guidelines.md](https://github.com/EducationalMaterialUiO/MachineLearningUiO/blob/main/LLM_Usage_Declaration_Guidelines.md).
#
# ### How Project 1 is graded (100 points)
#
# | Criterion | Points |
# |---|---:|
# | Abstract: accurate and informative? | 5 |
# | Introduction: status of the problem and the major objectives | 10 |
# | Formalism/methods: discussion of the methods used and their suitability | 10 |
# | Code, implementation and testing: readability, tests, benchmarks | 10 |
# | Analysis of results: selection, presentation, understanding | 40 |
# | Conclusions, discussions and critical comments; future improvements | 10 |
# | LLM declaration | 5 |
# | Overall presentation: figures, tables, algorithms | 5 |
# | Referencing: relevant works cited accurately? | 5 |
#
# The five pieces you write this week are worth 35 of the 100 points.
#
# Your task this week is to
#
# 1. write an abstract for your project,
# 2. write an introduction,
# 3. write a conclusion,
# 4. include references,
# 5. write the appendix declaring your usage of large language models.
#
# Hand in the five pieces as one document (a PDF from LaTeX, or this notebook).
# Placeholders for numbers you do not have yet are fine: write $[\,]$ and fill
# them in when the report is finished.

# %% [markdown]
# ## Exercise 1: the abstract
#
# The abstract gives the reader a quick overview of what has been done and the
# most important results. Try to be to the point and state your main findings.
# It can be structured in five moves:
#
# 1. a short introduction to the topic and why it is important,
# 2. a challenge or unresolved issue with the topic (that you will try to solve),
# 3. what you have done to solve this,
# 4. the main results,
# 5. the implications.
#
# Write the abstract of your Project 1 report: 120–180 words, one paragraph, no
# citations and no equations. Use the past tense for what you did and the
# present tense for what is true, and "we" also if you are a single author.
# State the main result as a number or as a comparison (for example the degree
# at which the test error is minimised, or which optimiser reproduced the
# closed-form solution fastest). Numbers you do not have yet are placeholders.
#
# Read your abstract once more and remove every sentence that could appear in
# *any* Project 1 report; those sentences carry no information. An abstract that
# only announces what you "will do" is a plan, not an abstract.
#
# **Your abstract:**
#
# > ...

# %% [markdown]
# Dette prosjektet er en vandring gjennom metodene innen dataanalyse som har ledet til det vi idag kaller maskinlæring. Hovedmålet er å studere i detalj diverese regresjonsmetoder, som ordinary least squares, ridge regresjon og lasso regresjon. Resampling teknikker som bootstrap og kryssvalidering lar oss vurdere og velge den beste metoden for problemet. For å optimalisere parametrene (hvilke parametre er det her snakk om?: det er selve parametrene og hyperparametrene) vil vi bruke gradient descent, og teste ulike metoder for å utføre denne beregningen, som består av derivasjon. Vi har studert newtons metode og automatiserte derivasjons metoder, for å optimalisere parametrene i modellene. Polynomene vi utvikler skal passe til en spesifik en dimensjonal funksjon kal Runges funksjon, med et støy element, dette medfører at vi vil ha det analytiske svaret tilgjengelig.

# %%
abstract = """

"""
print(len(abstract.split()), "words; target 120-180")
# Out:
# 101 words; target 120-180

# %% [markdown]
# ## Exercise 2: the introduction
#
# When you write the introduction you could focus on the following aspects:
#
# * motivate the reader — the first part of the introduction always gives a
#   motivation and tries to give the overarching ideas;
# * what I have done;
# * the structure of the report, how it is organised.
#
# Write the introduction of your Project 1 report (about one page).
#
# **2a)** The motivation. Why does one fit functions with polynomials at all,
# and why is Runge's function $1/(1+25x^2)$ the classic test case? What goes
# wrong at high polynomial degree, and what is the general lesson (the
# bias–variance trade-off, Section 2.10 of the lecture notes)? Cite the sources
# you actually used.
#
# **2b)** What has been done and what you do. One paragraph each on the linear
# models (OLS, Ridge, Lasso; Chapter 3), the resampling methods (bootstrap and
# $k$-fold cross-validation; Sections 2.11 and 3.14) and the optimisers
# (gradient descent, momentum, AdaGrad, RMSProp, Adam and stochastic gradient
# descent; Chapter 4). State explicitly what is *your* contribution (own
# implementations, own derivations, own experiments) and what is a library call
# (using `scikit-learn` for cross-validation is fine, but say so).
#
# **2c)** The structure of the report, always as the last paragraph: one
# sentence per section, and where the code can be found.
#
# Results do not belong in the introduction (the abstract may quote them; the
# introduction says *that* and *how* you compare); neither do long derivations
# or the definitions of the MSE and $R^2$, which belong to the methods section.
#
# **Your introduction:**
#
# > 2a) ...
# >
# > 2b) ...
# >
# > 2c) ...

# %% [markdown]
# **2a)** The motivation. Why does one fit functions with polynomials at all,
# and why is Runge's function $1/(1+25x^2)$ the classic test case? What goes
# wrong at high polynomial degree, and what is the general lesson (the
# bias–variance trade-off, Section 2.10 of the lecture notes)? Cite the sources
# you actually used.

# %% [markdown]
# En av grunnene til å tilpasse funksjoner med polynomer, er at man kan øke polynomgraden vilkårlig, og dermed utforske ulike polynomgrader med tilhørende parametre for å se hvilken polynomgrad som gir en best tilpasning. En utfordring er at man tilsynelatende kan få en optimal tilpasning ved å øke polynomgraden, og dermed bedre tilpasse polynomet til dataen man ønsker å beskrive, med en grunntanke om at dataen har en slags sammenheng som kan beskrives med et polynom, dvs. en funksjon. Ved å justere parametrene, vekten til hver enkelt polynomgrad, kan de ulike gradene bety mer eller mindre for å beskrive dataene. Runge funksjon er en klassisk test funksjon fordi den oppfører seg som en gaussisk fordeling i intervallet $[-1,1]$ , utenfor dette intervallet er funksjonen forholdsvis glatt og flat. For runge og polynomtilpasning vil dette si at en stadig høyere polynomgrad ikke nødvendigvis gir en bedre modell, dette fenomenet kalles overtilpasning.
# Dette fenomenet blir tydelig dersom man kartlegger "bias-variance" tradeoff. Dersom man tilpasser polynomer av økende grad, vil man se at feilen mellom modellen og treningsdataen blir mindre for høyere kompleksitet, derimot vil feilen mellom modellen og test data, etter at initielt har falt, gradvis øke med høyere kompleksitet. At test error gradvis øker, og trening error gradvis minker, er et resultat av bias og varians, ved høyere kompleksitet, blir bias mindre, som blir tydelig gjennom trening error, variansen vil derimot øke, som blir tydelig gjennom test erroren. Det er slik ettersom erroren er en sum av kvadrert bias, varians og kvadrert støy. At bias minker for treningsdata, er et tegn på overtilpasning, at variansen øker, dette forstår jeg ikke.

# %% [markdown]
# ## Exercise 3: the conclusion
#
# The conclusion should
#
# * state your main findings and interpretations,
# * try as far as possible to present perspectives for future work,
# * try to discuss the pros and cons of the methods and possible improvements.
#
# Write the conclusion of your Project 1 report in three paragraphs.
#
# **3a)** The main findings, explained. The numbers of the abstract, now with
# the reason behind them: why is the test error minimised where it is, why does
# Ridge extend the usable range of degrees, why does Lasso set the coefficients
# it sets to zero, why does gradient descent need standardised features. No
# sentence should repeat the abstract verbatim.
#
# **3b)** The critical paragraph. What the methods could and could not do, what
# you would do differently, and where your results are least certain (for
# instance a learning-rate grid too coarse to rank two optimisers, a fixed
# iteration count instead of a tolerance, a bias estimate that uses the known
# function). Write this paragraph first; it is the hardest and the most
# valuable, and a limitation you state yourself raises the score under
# "critical comments", while one the grader finds lowers it.
#
# **3c)** Perspectives. The one or two things you would do next and why,
# concretely ("the Lasso path with warm starts along $\lambda$", "a
# validation-based stopping rule for SGD"), not "more research is needed".
#
# **Your conclusion:**
#
# > 3a) ...
# >
# > 3b) ...
# >
# > 3c) ...

# %% [markdown]
# ## Exercise 4: references
#
# Give always references to material you base your work on, either scientific
# articles/reports or books:
#
# * refer to articles as: name(s) of author(s), journal, **volume** (boldfaced),
#   page and year in parenthesis;
# * refer to books as: name(s) of author(s), title of book, publisher, place and
#   year, eventual page numbers.
#
# **4a)** Set up the reference list of your report, preferably as a BibTeX file
# (with revtex, see the LaTeX example, use the style `apsrev4-1`; with the
# `article` class `unsrt` or `plain` do). Cite what you have used: the lecture
# notes and the textbooks (Hastie et al., Goodfellow et al.), the papers behind
# the methods (Ridge: A. E. Hoerl and R. W. Kennard, Technometrics **12**, 55
# (1970); Lasso: R. Tibshirani, J. R. Stat. Soc. B **58**, 267 (1996); Adam:
# D. P. Kingma and J. Ba, ICLR 2015; scikit-learn: F. Pedregosa et al., J. Mach.
# Learn. Res. **12**, 2825 (2011)), and the software you depend on. Every entry
# in the list must be cited at least once in the text. A starting `.bib` file is
# in `week39tuesday.ipynb`.
#
# **4b)** Verify every reference against the actual source (the journal page or
# the DOI), not against a language model: authors, year, volume, pages, and that
# the source says what you claim. Language models invent plausible references
# with real authors and wrong details. An unverified reference in your report is
# your error, and "relevant works cited accurately?" is the grading criterion.
#
# With a UiO IP number you can access freely all books and scientific journals
# available at our [University library](http://www.ub.uio.no/).
#
# **Your reference list (BibTeX or `\bibitem`s), each entry verified:**
#
# ```bibtex
# @book{hastie2009,
#   author    = {Hastie, Trevor and Tibshirani, Robert and Friedman, Jerome},
#   title     = {The Elements of Statistical Learning},
#   edition   = {2},
#   publisher = {Springer},
#   address   = {New York},
#   year      = {2009}
# }
# ```

# %% [markdown]
# ## Exercise 5: declaring the use of large language models
#
# Large language models (ChatGPT, Claude, GitHub Copilot, Gemini and similar)
# are permitted and encouraged in this course. Using one does not reduce your
# intellectual responsibility for what you submit: every result, derivation,
# code block and argument must be something you understand, can defend and have
# verified. Any significant use must be declared; concealment, not use, is the
# violation of academic integrity. The declaration counts 5 points of the
# project grade. The full rules are in the
# [guidelines](https://github.com/EducationalMaterialUiO/MachineLearningUiO/blob/main/LLM_Usage_Declaration_Guidelines.md).
#
# **5a)** Add an appendix "Use of AI/LLM Tools" to your report with
#
# * **A.1 Tools used:** every tool with name, version or access date, and
#   access method (for example "Claude (claude.ai, September 2026)", "GitHub
#   Copilot (VS Code, throughout)").
# * **A.2 Text writing and editing:** one contribution level per section of the
#   report, with a short note. The levels are 0 (none), 1 (language only:
#   spelling, grammar, minor phrasing), 2 (editorial: the model rewrote or
#   restructured your sentences, you supplied the ideas and checked the result)
#   and 3 (generative: the model drafted substantial text from your prompts;
#   you revised, verified and own it). For every level-3 section add a sentence
#   on the prompt you used and on what you changed.
# * **A.3 Code generation and assistance:** one level per code file or
#   notebook, with a description. The levels are 0 (none), 1 (debugging: the
#   model identified a bug, you fixed it), 2 (snippet: a function, loop or
#   short block that you integrated and tested), 3 (skeleton: the model
#   generated the structure, you filled in the logic) and 4 (substantial: the
#   model wrote most of the file, you adapted, tested and commented it).
#
# Fill it in for what you have actually done so far: the abstract, introduction
# and conclusion you wrote this week, and the code you have written for
# Project 1. Update it when the report is finished. The helper
# `llm_appendix` in `week39tuesday.ipynb` prints the tables as LaTeX.
#
# **5b)** In the code: add a `LLM-assisted` tag to the docstring of every
# function where a model contributed at level 2 or above (tool, role, your
# modifications and how you verified it), an inline comment for shorter
# generated blocks, and a markdown cell above every assisted notebook cell. The
# appendix and the docstrings must tell the same story.
#
# **5c)** Explaining a concept with a language model and then writing the
# section yourself, or a literature search whose citations you verified, need
# not be declared. Give one example from your own work of a use that must be
# declared and one that need not, and say why.
#
# **Your appendix:**
#
# **A.1 Tools used:** ...
#
# | Section | Level | Notes |
# |---|---|---|
# | Abstract | ? | ... |
# | Introduction | ? | ... |
# | Theory / Methods | ? | ... |
# | Code, implementation, tests | ? | ... |
# | Results and discussion | ? | ... |
# | Conclusion | ? | ... |
#
# | File / notebook | Level | Description |
# |---|---|---|
# | `...` | ? | ... |
#
# **5c)** ...

# %% [markdown]
# ## Insights you should have gained this week — a self-check
#
# Before you hand in, go through the list below without looking at the notes.
# Each row is a question we may ask in the Tuesday session or about Project 1;
# the right-hand column is the insight it tests, in one sentence.
#
# | Ask yourself | The insight it tests |
# |---|---|
# | Which five moves does an abstract make, and which of them is missing from "in this project we will implement OLS, Ridge and Lasso"? | An abstract reports work that was done, with a result; a plan is not an abstract. |
# | Does the number "test MSE 0.0121 at degree 7" belong in the abstract, the introduction, or both? | The abstract quotes the main result; the introduction says *that* and *how* you compare; the Results section has the numbers. |
# | Why does the introduction end with the structure of the report when the table of contents already lists the sections? | The last paragraph states the argument of the report and where each step lives; the table of contents only lists headings. |
# | Where does the reader learn that cross-validation used `scikit-learn` and everything else is your own code? | In the introduction's "what we did" paragraph; the grader credits code and tests only for what is yours. |
# | What distinguishes a conclusion from a second abstract? | The conclusion explains the findings, criticises the methods and gives concrete perspectives. |
# | Does stating a limitation of your own results lower the score? | No: critical comments are graded; a limitation the grader finds and you did not mention lowers it. |
# | How are an article and a book referenced in this course? | Authors, journal, **volume**, page (year); authors, title, publisher, place, year. |
# | What do you do with a reference suggested by a language model? | Open the source and verify authors, year, volume, pages and content; an unverified reference is your error. |
# | You used an LLM as a tutor and wrote the section yourself: which level? You pasted its derivation and fixed the notation: which level? | Level 0 is not declared; level 3 is declared with the prompt and your changes. |
# | Copilot autocompleted boilerplate line by line: what is declared? | Once, at file level; multi-line non-trivial suggestions get a file-level note and the docstring tag. |
# | Where must the same LLM use be visible twice? | In the appendix table and in the `LLM-assisted` docstring tag of the function. |
#
# ### Practicalities
#
# Deliver the five pieces as one document (a PDF from LaTeX, or this single
# Jupyter notebook) in Canvas before **Friday September 25 at midnight**.
# Collaboration is encouraged — write the pieces with your project group and
# list your collaborators. You get short feedback before the Project 1 deadline
# (**October 5**) and reuse the pieces in the report. Project 1 must contain the
# appendix on the use of AI/LLM tools; a missing declaration costs the 5 points
# of that criterion.
